# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/KokkulaKartikeya/Flyrank-ML-Internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*
# One row represents a single unique webpage URL for a specific client during a monthly aggregation window. For this contract, we are looking at the mid-panel month of March 2026 (2026-03) to ensure a complete, unskewed observation and outcome window without touching the final sealed test month.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*
# Features (max 5):
#
# 1.clicks_prior — knowable at decision moment because it measures past historical search traffic. 2.impressions_prior — knowable at decision moment from prior months' search console logs. 3.avg_position_prior — knowable at decision moment based on past average ranking. 4.ctr_prior — knowable at decision moment from historical click-through rates. 5.content_length_proxy — knowable at decision moment by inspecting the page static layout. Label: clicks_next_month — the target performance metric we want to predict and improve through content updates. Context: client_hash_id and page_path — used strictly as identifiers to map rows, not as predictive features. Excluded: actual_conversions_next_month or future_revenue — excluded deliberately because they represent future target outcomes and would cause data leakage if included at the decision timestamp.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*
# We ran verification checks on the March 2026 mid-panel data. The query confirms the unique grain of our slice, verifies the total row counts and date span, and ensures that availability conditions filtered properly using IS TRUE.

# %%
import os
from google.colab import userdata
from datasets import load_dataset

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")

print("Connecting to FlyRank Internship Warehouse...")
dataset = load_dataset("FlyRank/internship-warehouse", "dim_clients", split="train", streaming=True)

for row in dataset.take(1):
    print("Success! Data loaded:")
    print(row)
# Out:
# Connecting to FlyRank Internship Warehouse...
# Success! Data loaded:
# {'client_hash_id': 'client_04660893ae39614a', 'is_active': True, 'has_gsc_access': True, 'has_ga4_access': True, 'access_profile': 'gsc_and_ga4', 'client_created_date': datetime.date(2026, 4, 15), 'client_updated_date': datetime.date(2026, 6, 27), 'gsc_data_start': None, 'ga4_data_start': datetime.date(2026, 5, 22)}

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*
# This warehouse data cannot tell us about offline marketing campaigns, brand-new competitor actions outside organic search, or sudden short-term user intent shifts. It is limited to aggregated monthly Google Search Console and Analytics signals with historical coverage constraints.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
