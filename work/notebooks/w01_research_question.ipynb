# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/KokkulaKartikeya/Flyrank-ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1.Content Refresh Priority Lane
#
# I chose this lane because deciding which existing web pages need content updates is a high-impact task for SEO performance, helping content teams focus their efforts where they yield the highest return.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Decision: Which pages need a content refresh or structural update this month?
#
# Action: An SEO specialist or content writer updates and re-optimizes the flagged pages.
#
# Cost of a wrong call: False positives waste expensive writer hours updating pages that didn't need it. False negatives mean losing organic search traffic and search engine rankings.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

try:
    df = pd.read_csv('https://raw.githubusercontent.com/KokkulaKartikeya/Flyrank-ML-Internship/main/data/raw/content_refresh_anonymized.csv')
except Exception:
    df = pd.read_csv('data/raw/content_refresh_anonymized.csv')

print(f"Total pages: {len(df)}")
print(f"Total columns: {len(df.columns)}")
# Out:
# Total pages: 30000
# Total columns: 44

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# My work provides observed, directional, and decision-support metrics based on historical data patterns. I cannot claim that this model directly predicts Google’s proprietary ranking algorithm, nor does it guarantee absolute ranking improvements.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
